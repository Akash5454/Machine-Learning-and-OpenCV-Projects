# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd

# %%
import sklearn

# %%
from sklearn.naive_bayes import GaussianNB

# %%
df = pd.read_csv("Cancer.csv")

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.drop(['id','Unnamed: 32'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# compactness_se             569 non-null float64
# ...

# %%
df.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df[df['diagnosis'] == 'M'].shape
# Out:
# (212, 31)

# %%
df[df['diagnosis'] == 'B'].shape
# Out:
# (357, 31)

# %%
# unbalanced data B>M
# Data should be balanced 
training_data_len = int(0.7*df.shape[0])

# %%
training_data_len
# Out:
# 398

# %%
pos_class_training_data_len = int(training_data_len/2)

# %%
neg_class_training_data_len = int(training_data_len/2)

# %%
pos_class_training_data_len
# Out:
# 199

# %%
neg_class_training_data_len
# Out:
# 199

# %%
pos_class_training_data = df[df['diagnosis']=='M'].iloc[:pos_class_training_data_len]

# %%
pos_class_training_data.shape
# Out:
# (199, 31)

# %%
neg_class_training_data = df[df['diagnosis']=='B'].iloc[:neg_class_training_data_len]

# %%
neg_class_training_data.shape
# Out:
# (199, 31)

# %%
neg_class_training_labels = neg_class_training_data['diagnosis']
pos_class_training_labels = pos_class_training_data['diagnosis']
pos_class_training_labels.shape
# Out:
# (199,)

# %%
neg_class_training_labels.shape
# Out:
# (199,)

# %%
training_labels = pd.concat([neg_class_training_labels,pos_class_training_labels])

# %%
training_labels.shape
# Out:
# (398,)

# %%
neg_class_training_data.drop(['diagnosis'], axis=1,inplace=True)

# %%
neg_class_training_data.head()
# Out:
#     radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 19       13.540         14.36           87.46      566.3          0.09779
# 20       13.080         15.71           85.63      520.0          0.10750
# 21        9.504         12.44           60.34      273.9          0.10240
# 37       13.030         18.42           82.61      523.8          0.08983
# 46        8.196         16.84           51.71      201.9          0.08600
#
#     compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 19           0.08129         0.06664             0.047810         0.1885
# 20           0.12700         0.04568             0.031100         0.1967
# 21           0.06492         0.02956             0.020760         0.1815
# 37           0.03766         0.02562             0.029230         0.1467
# 46           0.05943         0.01588             0.005917         0.1769
#
#     fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
neg_class_training_data.shape
# Out:
# (199, 30)

# %%
pos_class_training_data.drop(['diagnosis'], axis=1,inplace=True)

# %%
pos_class_training_data.shape
# Out:
# (199, 30)

# %%
#till now we are proccessing the data and making it balanced
# we are making 398 instances for traning the model each have 199

# %%
training_data = pd.concat([neg_class_training_data, pos_class_training_data])

# %%
training_data
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 19        13.540         14.36           87.46      566.3          0.09779
# 20        13.080         15.71           85.63      520.0          0.10750
# 21         9.504         12.44           60.34      273.9          0.10240
# 37        13.030         18.42           82.61      523.8          0.08983
# 46         8.196         16.84           51.71      201.9          0.08600
# 48        12.050         14.63           78.04      449.3          0.10310
# 49        13.490         22.30           86.91      561.0          0.08752
# 50        11.760         21.60           74.72      427.9          0.08637
# 51        13.640         16.34           87.21      571.8          0.07685
# 52        11.940         18.24           75.71      437.6          0.08261
# 55        11.520         18.75           73.34      409.0          0.09524
# ...

# %%
naive_bayes_obj = GaussianNB()

# %%
naive_bayes_obj.fit(X=training_data, y=training_labels)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
pos_class_data = df[df['diagnosis'] == 'M'].iloc[198:]

# %%
pos_class_data.shape
# Out:
# (14, 31)

# %%
pos_class_data
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 512         M        13.40         20.52           88.64      556.7
# 514         M        15.05         19.07           97.26      701.9
# 516         M        18.31         20.58          120.80     1052.0
# 517         M        19.89         20.26          130.50     1214.0
# 521         M        24.63         21.60          165.50     1841.0
# 533         M        20.47         20.67          134.70     1299.0
# 535         M        20.55         20.86          137.80     1308.0
# 536         M        14.27         22.55           93.77      629.8
# 562         M        15.22         30.62          103.40      716.9
# 563         M        20.92         25.09          143.00     1347.0
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# ...

# %%
neg_class_data = df[df['diagnosis'] == 'B'].iloc[198:]

# %%
neg_class_data.shape
# Out:
# (159, 31)

# %%
neg_class_data
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 359         B        9.436         18.32           59.82      278.6
# 360         B       12.540         18.07           79.42      491.9
# 361         B       13.300         21.57           85.24      546.1
# 362         B       12.760         18.84           81.87      496.6
# 363         B       16.500         18.29          106.60      838.1
# 364         B       13.400         16.95           85.48      552.4
# 367         B       12.210         18.02           78.31      458.4
# 371         B       15.190         13.21           97.65      711.8
# 374         B       13.690         16.07           87.84      579.1
# 375         B       16.170         16.07          106.30      788.5
# 376         B       10.570         20.22           70.15      338.3
# 377         B       13.460         28.21           85.89      562.1
# 378         B       13.660         15.15           88.27      580.6
# ...

# %%
pos_class_testing_labels = pos_class_data['diagnosis']
neg_class_testing_labels = neg_class_data['diagnosis']

# %%
pos_class_testing_labels.shape
# Out:
# (14,)

# %%
neg_class_testing_labels.shape
# Out:
# (159,)

# %%
neg_class_testing_data = neg_class_data.drop(['diagnosis'], axis=1, inplace=True)

# %%
pos_class_testing_data = pos_class_data.drop(['diagnosis'], axis=1, inplace=True)

# %%
testing_data_labels = pd.concat([neg_class_testing_labels,pos_class_testing_labels])

# %%
testing_data = pd.concat([neg_class_data, pos_class_data])

# %%
testing_data
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 359        9.436         18.32           59.82      278.6          0.10090
# 360       12.540         18.07           79.42      491.9          0.07436
# 361       13.300         21.57           85.24      546.1          0.08582
# 362       12.760         18.84           81.87      496.6          0.09676
# 363       16.500         18.29          106.60      838.1          0.09686
# 364       13.400         16.95           85.48      552.4          0.07937
# 367       12.210         18.02           78.31      458.4          0.09231
# 371       15.190         13.21           97.65      711.8          0.07963
# 374       13.690         16.07           87.84      579.1          0.08302
# 375       16.170         16.07          106.30      788.5          0.09880
# 376       10.570         20.22           70.15      338.3          0.09073
# ...

# %%
testing_data_labels.shape
# Out:
# (173,)

# %%
pred = naive_bayes_obj.predict(testing_data)

# %%
pred
# Out:
# array(['B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'B', 'M', 'M', 'M', 'M', 'M', 'B', 'M', 'M',
# ...

# %%
pred = np.array(pred)

# %%
testing_data_labels = np.array(testing_data_labels)

# %%
testing_data_labels.shape
# Out:
# (173,)

# %%
pred.shape
# Out:
# (173,)

# %%
testing_data
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 359        9.436         18.32           59.82      278.6          0.10090
# 360       12.540         18.07           79.42      491.9          0.07436
# 361       13.300         21.57           85.24      546.1          0.08582
# 362       12.760         18.84           81.87      496.6          0.09676
# 363       16.500         18.29          106.60      838.1          0.09686
# 364       13.400         16.95           85.48      552.4          0.07937
# 367       12.210         18.02           78.31      458.4          0.09231
# 371       15.190         13.21           97.65      711.8          0.07963
# 374       13.690         16.07           87.84      579.1          0.08302
# 375       16.170         16.07          106.30      788.5          0.09880
# 376       10.570         20.22           70.15      338.3          0.09073
# ...

# %%
testing_data_labels
# Out:
# array(['B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
# ...

# %%
np.equal(testing_data_labels,pred)
# Out:
# array([ True,  True,  True,  True, False,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True, False,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True, False,  True,  True,
#         True,  True, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %%
accuracy = 165/173

# %%
accuracy
# Out:
# 0.953757225433526
